# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
#from nltk.stem import SnowballStemmer
#import nltk
#nltk.download('wordnet')

# %%
events = pd.read_excel("Event.xlsx")
target_names = events.Type.unique().tolist()

# %%
events
# Out:
#                                                  Events  \
# 0                      Management 2020 hackathon is out
# 1         Attend a mangament hackathon of your choosing
# 2     Hackathons and more: Management hackathon is h...
# 3              Introducing The Management 2.0 Hackathon
# 4     Join us live online on September 10th at 9:30 ...
# ...                                                 ...
# 1508                  Codemaster hackathon begins today
# 1509  the fans asked so we ansewered your wishes. Ou...
# 1510  Hackathons and codeathons: Join us for a one o...
# 1511  Hackathons have been part of the world for an ...
# 1512               Come down for the codeVIta hackathon
#
#                        Type Unnamed: 2
# 0     Management.Hackathons        NaN
# 1     Management.Hackathons        NaN
# 2     Management.Hackathons        NaN
# 3     Management.Hackathons        NaN
# 4       Management.Webinars        NaN
# ...                     ...        ...
# 1508         None.Hackathon        NaN
# 1509         None.Hackathon        NaN
# 1510         None.Hackathon        NaN
# 1511         None.Hackathon        NaN
# 1512         None.Hackathon        NaN
#
# [1513 rows x 3 columns]

# %%
events['category_id'] = events['Type'].factorize()[0]

# %%
category_id_df = events[['Type', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Type']].values)

# %%
def split_lemma(event_list):#stemmer = SnowballStemmer("english")
    #stemmer = SnowballStemmer("english")
    lemma = WordNetLemmatizer()

    output = []
    for sentence in event_list:
        output.append(" ".join([lemma.lemmatize(i) for i in sentence.split()]))
    return output
events['Events_stemmed'] = split_lemma(events.Events)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text


my_stops = text.ENGLISH_STOP_WORDS.difference(["AI", "ai"])

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words= my_stops, token_pattern = r"(?u)c\+{2}|\b\w+\b")
features = tfidf.fit_transform(events.Events_stemmed.values)
labels = events.Type
features.shape
# Out:
# (1513, 2587)

# %%
from sklearn.feature_selection import chi2
N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Artificial_Intelligence.Certifications':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Courses':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Expos':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Fests':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Hackathons':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Internships':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Jobs':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Seminars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Talks':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Trainings':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Artificial_Intelligence.Webinars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Certifications':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Competitions':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Courses':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Expos':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Fests':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Hackathons':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Internships':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Jobs':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Seminars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Talks':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Trainings':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Webinars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Blockchain.Workshops':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Certifications':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Competitions':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Courses':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Expos':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Fests':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Hackathons':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Internships':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Jobs':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Seminars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Talks':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Trainings':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Webinars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'C.Workshops':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Certifications':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Competitions':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Courses':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Expos':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Fests':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Hackathons':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Internships':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Jobs':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Seminars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Talks':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Trainings':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Webinars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'CC.Workshops':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Certifications':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Competitions':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Expos':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Fests':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Hackathons':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Internships':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Jobs':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Seminars':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# # 'Coding.Talks':
#   . Most correlated unigrams:
# . eduat
# . educ
#   . Most correlated bigrams:
# . educ depart
# . educ expert
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-13f33ef7dc1f> in <module>
#       2 N = 2
#       3 for Product, category_id in sorted(category_to_id.items()):
# ----> 4   features_chi2 = chi2(features, labels == category_id)
#       5   indices = np.argsort(features_chi2[0])
#       6   feature_names = np.array(tfidf.get_feature_names())[indices]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in chi2(X, y)
#     226     expected = np.dot(class_prob.T, feature_count)
#     227
# --> 228     return _chisquare(observed, expected)
#     229
#     230
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in _chisquare(f_obs, f_exp)
#     167         chisq /= f_exp
#     168     chisq = chisq.sum(axis=0)
# --> 169     return chisq, special.chdtrc(k - 1, chisq)
#     170
#     171
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(events.Events, events.Type, random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["Internship Opportunity: Full time python job"])))
# Out:
# ['Mobile_Applications.Jobs']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\shiva\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\shiva\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\shiva\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9caff631d240> in <module>
#      23 sns.stripplot(x='model_name', y='accuracy', data=cv_df,
#      24               size=8, jitter=True, edgecolor="gray", linewidth=2)
# ---> 25 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split

model = LinearSVC()

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, events.index, test_size=0.01, random_state=0)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Type.values, yticklabels=category_id_df.Type.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f19aab05270f> in <module>
#       3 conf_mat = confusion_matrix(y_test, y_pred)
#       4 fig, ax = plt.subplots(figsize=(20,20))
# ----> 5 sns.heatmap(conf_mat, annot=True, fmt='d',
#       6             xticklabels=category_id_df.Type.values, yticklabels=category_id_df.Type.values)
#       7 plt.ylabel('Actual')
#
# NameError: name 'sns' is not defined

# %%
#model = LinearSVC()

model.fit(features, labels)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
from sklearn.feature_selection import chi2

N = 2
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Product))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'Artificial_Intelligence.Certifications':
#   . Top unigrams:
#        . internship
#        . c
#   . Top bigrams:
#        . c programming
#        . sign today
# # 'Artificial_Intelligence.Courses':
#   . Top unigrams:
#        . project
#        . c
#   . Top bigrams:
#        . job opening
#        . naukri com
# # 'Artificial_Intelligence.Expos':
#   . Top unigrams:
#        . fest
#        . c
#   . Top bigrams:
#        . c language
#        . c programming
# # 'Artificial_Intelligence.Fests':
#   . Top unigrams:
#        . course
#        . date
#   . Top bigrams:
#        . join course
#        . objective c
# # 'Artificial_Intelligence.Hackathons':
#   . Top unigrams:
#        . certified
#        . c
#   . Top bigrams:
#        . developer today
#        . c programming
# # 'Artificial_Intelligence.Internships':
#   . Top unigrams:
#        . popular
#        . c
#   . Top bigrams:
#        . talk series
#        . talks speeches
# # 'Artificial_Intelligence.Jobs':
#   . Top unigrams:
#        . c
#        . conference
#   . Top bigrams:
#        . conferences seminars
#        . programming language
# # 'Artificial_Intelligence.Seminars':
#   . Top unigrams:
#        . c
#        . fair
#   . Top bigrams:
#        . c expo
#        . book ticket
# # 'Artificial_Intelligence.Talks':
#   . Top unigrams:
#        . c
#        . add
#   . Top bigrams:
#        . join u
#        . objective c
# # 'Artificial_Intelligence.Trainings':
#   . Top unigrams:
#        . c
#        . live
#   . Top bigrams:
#        . hackathons codeathons
#        . c language
# # 'Artificial_Intelligence.Webinars':
#   . Top unigrams:
#        . fellow
#        . c
#   . Top bigrams:
#        . think know
#        . join u
# # 'Blockchain.Certifications':
#   . Top unigrams:
#        . hackathon
#        . android
#   . Top bigrams:
#        . mobile app
#        . registration open
# # 'Blockchain.Competitions':
#   . Top unigrams:
#        . build
#        . webinar
#   . Top bigrams:
#        . app development
#        . mobile apps
# # 'Blockchain.Courses':
#   . Top unigrams:
#        . work
#        . excecutive
#   . Top bigrams:
#        . job alert
#        . developer job
# # 'Blockchain.Expos':
#   . Top unigrams:
#        . web
#        . conference
#   . Top bigrams:
#        . attend free
#        . free web
# # 'Blockchain.Fests':
#   . Top unigrams:
#        . fest
#        . festival
#   . Top bigrams:
#        . dev fest
#        . apple ios
# # 'Blockchain.Hackathons':
#   . Top unigrams:
#        . complete
#        . course
#   . Top bigrams:
#        . want learn
#        . mobile application
# # 'Blockchain.Internships':
#   . Top unigrams:
#        . train
#        . 2
#   . Top bigrams:
#        . mobile application
#        . android io
# # 'Blockchain.Jobs':
#   . Top unigrams:
#        . soon
#        . mobile
#   . Top bigrams:
#        . world s
#        . mobile applications
# # 'Blockchain.Seminars':
#   . Top unigrams:
#        . engineer
#        . internship
#   . Top bigrams:
#        . time position
#        . internship opportunity
# # 'Blockchain.Talks':
#   . Top unigrams:
#        . workshop
#        . complete
#   . Top bigrams:
#        . development workshop
#        . want learn
# # 'Blockchain.Trainings':
#   . Top unigrams:
#        . future
#        . usage
#   . Top bigrams:
#        . mobile application
#        . mobile applications
# # 'Blockchain.Webinars':
#   . Top unigrams:
#        . love
#        . expo
#   . Top bigrams:
#        . fairs come
#        . mobile apps
# # 'Blockchain.Workshops':
#   . Top unigrams:
#        . networking
#        . network
#   . Top bigrams:
#        . networking network
#        . today certification
# # 'C.Certifications':
#   . Top unigrams:
#        . bank
#        . resume
#   . Top bigrams:
#        . finance trading
#        . internationally recognized
# # 'C.Competitions':
#   . Top unigrams:
#        . weekend
#        . banking
#   . Top bigrams:
#        . banking seminar
#        . finance investment
# # 'C.Courses':
#   . Top unigrams:
#        . course
#        . finance
#   . Top bigrams:
#        . learning course
#        . finance investment
# # 'C.Expos':
#   . Top unigrams:
#        . festival
#        . institute
#   . Top bigrams:
#        . fest 2020
#        . finance investment
# # 'C.Fests':
#   . Top unigrams:
#        . workshop
#        . data
#   . Top bigrams:
#        . science workshop
#        . data science
# # 'C.Hackathons':
#   . Top unigrams:
#        . science
#        . data
#   . Top bigrams:
#        . sign data
#        . data science
# # 'C.Internships':
#   . Top unigrams:
#        . financial
#        . analyst
#   . Top bigrams:
#        . job alert
#        . job opportunity
# # 'C.Jobs':
#   . Top unigrams:
#        . hackathon
#        . banking
#   . Top bigrams:
#        . finance banking
#        . registrations open
# # 'C.Seminars':
#   . Top unigrams:
#        . register
#        . competition
#   . Top bigrams:
#        . webinar series
#        . fairs annual
# # 'C.Talks':
#   . Top unigrams:
#        . financial
#        . panel
#   . Top bigrams:
#        . home option
#        . available perfect
# # 'C.Trainings':
#   . Top unigrams:
#        . consultant
#        . banking
#   . Top bigrams:
#        . available naukri
#        . naukri com
# # 'C.Webinars':
#   . Top unigrams:
#        . science
#        . data
#   . Top bigrams:
#        . science webinar
#        . build data
# # 'C.Workshops':
#   . Top unigrams:
#        . webinar
#        . markets
#   . Top bigrams:
#        . online session
#        . live online
# # 'CC.Certifications':
#   . Top unigrams:
#        . course
#        . introduction
#   . Top bigrams:
#        . python programming
#        . expert certification
# # 'CC.Competitions':
#   . Top unigrams:
#        . conference
#        . python
#   . Top bigrams:
#        . largest python
#        . seminar today
# # 'CC.Courses':
#   . Top unigrams:
#        . festival
#        . python
#   . Top bigrams:
#        . python fest
#        . coming soon
# # 'CC.Expos':
#   . Top unigrams:
#        . speech
#        . web
#   . Top bigrams:
#        . speech web
#        . web development
# # 'CC.Fests':
#   . Top unigrams:
#        . contest
#        . themed
#   . Top bigrams:
#        . join python
#        . python programming
# # 'CC.Hackathons':
#   . Top unigrams:
#        . environment
#        . college
#   . Top bigrams:
#        . competition today
#        . hardware machine
# # 'CC.Internships':
#   . Top unigrams:
#        . job
#        . python
#   . Top bigrams:
#        . job available
#        . time position
# # 'CC.Jobs':
#   . Top unigrams:
#        . hackathon
#        . python
#   . Top bigrams:
#        . python hackathon
#        . registrations open
# # 'CC.Seminars':
#   . Top unigrams:
#        . expo
#        . python
#   . Top bigrams:
#        . python expo
#        . expo fair
# # 'CC.Talks':
#   . Top unigrams:
#        . python
#        . code
#   . Top bigrams:
#        . attend speech
#        . talks speeches
# # 'CC.Trainings':
#   . Top unigrams:
#        . internship
#        . intern
#   . Top bigrams:
#        . development intern
#        . intern u
# # 'CC.Webinars':
#   . Top unigrams:
#        . certificate
#        . python
#   . Top bigrams:
#        . certified associate
#        . expert certificate
# # 'CC.Workshops':
#   . Top unigrams:
#        . week
#        . python
#   . Top bigrams:
#        . python bootcamp
#        . begin tomorrow
# # 'Coding.Certifications':
#   . Top unigrams:
#        . blockchain
#        . technique
#   . Top bigrams:
#        . build blockchain
#        . technique webinar
# # 'Coding.Competitions':
#   . Top unigrams:
#        . blockchain
#        . workshop
#   . Top bigrams:
#        . blockchain workshop
#        . annual blockchain
# # 'Coding.Expos':
#   . Top unigrams:
#        . blockchain
#        . blockchains
#   . Top bigrams:
#        . blockchain expert
#        . life cycle
# # 'Coding.Fests':
#   . Top unigrams:
#        . expo
#        . ai
#   . Top bigrams:
#        . intelligence expo
#        . expo today
# # 'Coding.Hackathons':
#   . Top unigrams:
#        . blockchain
#        . bootcamp
#   . Top bigrams:
#        . blockchain training
#        . training bootcamps
# # 'Coding.Internships':
#   . Top unigrams:
#        . blockchain
#        . skill
#   . Top bigrams:
#        . blockchain related
#        . maruti blockchain
# # 'Coding.Jobs':
#   . Top unigrams:
#        . blockchain
#        . design
#   . Top bigrams:
#        . blockchain intern
#        . blockchain internship
# # 'Coding.Seminars':
#   . Top unigrams:
#        . blockchain
#        . conference
#   . Top bigrams:
#        . annual blockchain
#        . free blockchain
# # 'Coding.Talks':
#   . Top unigrams:
#        . blockchain
#        . job
#   . Top bigrams:
#        . blockchain jobs
#        . blockchain expert
# # 'Coding.Webinars':
#   . Top unigrams:
#        . festival
#        . nz
#   . Top bigrams:
#        . exciting goody
#        . book ticket
# # 'Cpp.Certifications':
#   . Top unigrams:
#        . data
#        . science
#   . Top bigrams:
#        . science expert
#        . data science
# # 'Cpp.Competitions':
#   . Top unigrams:
#        . scientist
#        . job
#   . Top bigrams:
#        . science job
#        . scientist job
# # 'Cpp.Courses':
#   . Top unigrams:
#        . course
#        . data
#   . Top bigrams:
#        . science course
#        . data science
# # 'Cpp.Expos':
#   . Top unigrams:
#        . data
#        . analytics
#   . Top bigrams:
#        . world data
#        . explore world
# # 'Cpp.Fests':
#   . Top unigrams:
#        . bootcamp
#        . c++
#   . Top bigrams:
#        . join workshop
#        . registration open
# # 'Cpp.Hackathons':
#   . Top unigrams:
#        . training
#        . intermediate
#   . Top bigrams:
#        . advanced c++
#        . c++ programming
# # 'Cpp.Internships':
#   . Top unigrams:
#        . data
#        . internships
#   . Top bigrams:
#        . time internships
#        . data science
# # 'Cpp.Jobs':
#   . Top unigrams:
#        . data
#        . fest
#   . Top bigrams:
#        . science fest
#        . data mining
# # 'Cpp.Seminars':
#   . Top unigrams:
#        . data
#        . competition
#   . Top bigrams:
#        . science competition
#        . data science
# # 'Cpp.Talks':
#   . Top unigrams:
#        . data
#        . seminar
#   . Top bigrams:
#        . talk data
#        . annual data
# # 'Cpp.Trainings':
#   . Top unigrams:
#        . mining
#        . science
#   . Top bigrams:
#        . mining science
#        . science mining
# # 'Cpp.Webinars':
#   . Top unigrams:
#        . c++
#        . webinar
#   . Top bigrams:
#        . u online
#        . modern c++
# # 'Cpp.Workshops':
#   . Top unigrams:
#        . data
#        . science
#   . Top bigrams:
#        . talk data
#        . data science
# # 'Data_Science.Certifications':
#   . Top unigrams:
#        . security
#        . competition
#   . Top bigrams:
#        . security competition
#        . competition quiz
# # 'Data_Science.Competitions':
#   . Top unigrams:
#        . security
#        . handling
#   . Top bigrams:
#        . security job
#        . security jobs
# # 'Data_Science.Courses':
#   . Top unigrams:
#        . security
#        . special
#   . Top bigrams:
#        . explore world
#        . fair register
# # 'Data_Science.Expos':
#   . Top unigrams:
#        . training
#        . web
#   . Top bigrams:
#        . development training
#        . web dev
# # 'Data_Science.Fests':
#   . Top unigrams:
#        . security
#        . certification
#   . Top bigrams:
#        . security certification
#        . security expert
# # 'Data_Science.Hackathons':
#   . Top unigrams:
#        . webinar
#        . python
#   . Top bigrams:
#        . python programming
#        . live online
# # 'Data_Science.Internships':
#   . Top unigrams:
#        . handle
#        . security
#   . Top bigrams:
#        . security intern
#        . cyber security
# # 'Data_Science.Jobs':
#   . Top unigrams:
#        . security
#        . fest
#   . Top bigrams:
#        . cyber vulnerability
#        . sign explore
# # 'Data_Science.Seminars':
#   . Top unigrams:
#        . security
#        . course
#   . Top bigrams:
#        . security course
#        . sign security
# # 'Data_Science.Talks':
#   . Top unigrams:
#        . seminar
#        . security
#   . Top bigrams:
#        . free seminar
#        . cyber vulnerability
# # 'Data_Science.Trainings':
#   . Top unigrams:
#        . vulnerability
#        . hackathon
#   . Top bigrams:
#        . security vulnerability
#        . cyber vulnerability
# # 'Data_Science.Webinars':
#   . Top unigrams:
#        . workshop
#        . skill
#   . Top bigrams:
#        . python workshop
#        . workshop today
# # 'Data_Science.Workshops':
#   . Top unigrams:
#        . security
#        . cyber
#   . Top bigrams:
#        . security expert
#        . talk cyber
# # 'Finance.Certifications':
#   . Top unigrams:
#        . expo
#        . coding
#   . Top bigrams:
#        . coding expo
#        . attend host
# # 'Finance.Competitions':
#   . Top unigrams:
#        . speech
#        . talk
#   . Top bigrams:
#        . speeches talk
#        . artificial intelligence
# # 'Finance.Courses':
#   . Top unigrams:
#        . alert
#        . coding
#   . Top bigrams:
#        . quiz stand
#        . think know
# # 'Finance.Fests':
#   . Top unigrams:
#        . coding
#        . grab
#   . Top bigrams:
#        . stand rest
#        . high quality
# # 'Finance.Hackathons':
#   . Top unigrams:
#        . cloud
#        . webinar
#   . Top bigrams:
#        . build cloud
#        . cloud service
# # 'Finance.Internships':
#   . Top unigrams:
#        . solutions
#        . summer
#   . Top bigrams:
#        . summer internship
#        . bootcamps training
# # 'Finance.Jobs':
#   . Top unigrams:
#        . win
#        . hackathons
#   . Top bigrams:
#        . finally register
#        . fair finally
# # 'Finance.Seminars':
#   . Top unigrams:
#        . programmers
#        . coding
#   . Top bigrams:
#        . coding fest
#        . coding festival
# # 'Finance.Talks':
#   . Top unigrams:
#        . workshop
#        . aws
#   . Top bigrams:
#        . computing workshop
#        . cloud computing
# # 'Finance.Webinars':
#   . Top unigrams:
#        . training
#        . 3
#   . Top bigrams:
#        . intelligence training
#        . training bootcamp
# # 'Finance.Workshops':
#   . Top unigrams:
#        . junior
#        . developer
#   . Top bigrams:
#        . software developer
#        . contact u
# # 'Hardware.Certifications':
#   . Top unigrams:
#        . iot
#        . device
#   . Top bigrams:
#        . iot competition
#        . competition build
# # 'Hardware.Competitions':
#   . Top unigrams:
#        . iot
#        . job
#   . Top bigrams:
#        . iot expert
#        . internet things
# # 'Hardware.Courses':
#   . Top unigrams:
#        . iot
#        . thing
#   . Top bigrams:
#        . iot fair
#        . fair explore
# # 'Hardware.Expos':
#   . Top unigrams:
#        . fair
#        . come
#   . Top bigrams:
#        . development fair
#        . development fest
# # 'Hardware.Fests':
#   . Top unigrams:
#        . iot
#        . certification
#   . Top bigrams:
#        . iot expert
#        . expert certification
# # 'Hardware.Hackathons':
#   . Top unigrams:
#        . prepare
#        . webinars
#   . Top bigrams:
#        . education webinar
#        . pursue higher
# # 'Hardware.Internships':
#   . Top unigrams:
#        . iot
#        . device
#   . Top bigrams:
#        . build design
#        . professional environment
# # 'Hardware.Jobs':
#   . Top unigrams:
#        . iot
#        . fest
#   . Top bigrams:
#        . fest sign
#        . festivals avanse
# # 'Hardware.Seminars':
#   . Top unigrams:
#        . iot
#        . protocol
#   . Top bigrams:
#        . iot course
#        . iot protocol
# # 'Hardware.Talks':
#   . Top unigrams:
#        . iot
#        . conference
#   . Top bigrams:
#        . internet thing
#        . attend free
# # 'Hardware.Trainings':
#   . Top unigrams:
#        . iot
#        . protocol
#   . Top bigrams:
#        . iot protocol
#        . hackathon codeathon
# # 'Hardware.Webinars':
#   . Top unigrams:
#        . workshop
#        . education
#   . Top bigrams:
#        . education workshop
#        . free higher
# # 'Hardware.Workshops':
#   . Top unigrams:
#        . iot
#        . speech
#   . Top bigrams:
#        . talk iot
#        . talks speech
# # 'Higher_Education.Certifications':
#   . Top unigrams:
#        . architecture
#        . conference
#   . Top bigrams:
#        . software architecture
#        . annual software
# # 'Higher_Education.Competitions':
#   . Top unigrams:
#        . software
#        . architecture
#   . Top bigrams:
#        . build software
#        . software architecture
# # 'Higher_Education.Courses':
#   . Top unigrams:
#        . architecture
#        . speech
#   . Top bigrams:
#        . talk software
#        . software architecture
# # 'Higher_Education.Expos':
#   . Top unigrams:
#        . blockchain
#        . course
#   . Top bigrams:
#        . pro course
#        . build blockchain
# # 'Higher_Education.Fests':
#   . Top unigrams:
#        . architecture
#        . software
#   . Top bigrams:
#        . architecture job
#        . architecture jobs
# # 'Higher_Education.Hackathons':
#   . Top unigrams:
#        . architecture
#        . kernel
#   . Top bigrams:
#        . architecture intern
#        . kernel architecture
# # 'Higher_Education.Internships':
#   . Top unigrams:
#        . blockchain
#        . certification
#   . Top bigrams:
#        . blockchain expert
#        . certification available
# # 'Higher_Education.Jobs':
#   . Top unigrams:
#        . software
#        . architecture
#   . Top bigrams:
#        . software architecture
#        . architecture software
# # 'Higher_Education.Seminars':
#   . Top unigrams:
#        . blockchain
#        . blockchains
#   . Top bigrams:
#        . creator fair
#        . join fair
# # 'Higher_Education.Talks':
#   . Top unigrams:
#        . workshop
#        . architecture
#   . Top bigrams:
#        . architecture workshop
#        . architecture fair
# # 'Higher_Education.Trainings':
#   . Top unigrams:
#        . ai
#        . webinar
#   . Top bigrams:
#        . online webinar
#        . attend webinar
# # 'Higher_Education.Webinars':
#   . Top unigrams:
#        . blockchain
#        . competition
#   . Top bigrams:
#        . blockchain competition
#        . competition quiz
# # 'Higher_Education.Workshops':
#   . Top unigrams:
#        . development
#        . certifications
#   . Top bigrams:
#        . advanced certification
#        . certifications available
# # 'IoT.Certifications':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . javascript fair
#        . fairs expos
# # 'IoT.Competitions':
#   . Top unigrams:
#        . complex
#        . java
#   . Top bigrams:
#        . join java
#        . hackathons codeathons
# # 'IoT.Courses':
#   . Top unigrams:
#        . java
#        . compete
#   . Top bigrams:
#        . java competition
#        . win exciting
# # 'IoT.Expos':
#   . Top unigrams:
#        . web
#        . website
#   . Top bigrams:
#        . development fest
#        . love website
# # 'IoT.Fests':
#   . Top unigrams:
#        . iot
#        . workshop
#   . Top bigrams:
#        . iot fair
#        . internet things
# # 'IoT.Hackathons':
#   . Top unigrams:
#        . iot
#        . things
#   . Top bigrams:
#        . iot training
#        . internet device
# # 'IoT.Internships':
#   . Top unigrams:
#        . java
#        . fests
#   . Top bigrams:
#        . fest 2020
#        . coming soon
# # 'IoT.Jobs':
#   . Top unigrams:
#        . course
#        . java
#   . Top bigrams:
#        . java course
#        . join course
# # 'IoT.Seminars':
#   . Top unigrams:
#        . java
#        . proficiency
#   . Top bigrams:
#        . expert today
#        . java developer
# # 'IoT.Talks':
#   . Top unigrams:
#        . java
#        . interns
#   . Top bigrams:
#        . time java
#        . interns needed
# # 'IoT.Trainings':
#   . Top unigrams:
#        . java
#        . fair
#   . Top bigrams:
#        . java fair
#        . expo fair
# # 'IoT.Webinars':
#   . Top unigrams:
#        . iot
#        . series
#   . Top bigrams:
#        . ground knowledge
#        . webinar series
# # 'IoT.Workshops':
#   . Top unigrams:
#        . java
#        . excecutive
#   . Top bigrams:
#        . java developer
#        . developer job
# # 'JS.Expos':
#   . Top unigrams:
#        . competition
#        . web
#   . Top bigrams:
#        . development competition
#        . web development
# # 'Java.Certifications':
#   . Top unigrams:
#        . hardware
#        . course
#   . Top bigrams:
#        . hardware course
#        . build machine
# # 'Java.Competitions':
#   . Top unigrams:
#        . hardware
#        . speech
#   . Top bigrams:
#        . speech hardware
#        . hardware expert
# # 'Java.Courses':
#   . Top unigrams:
#        . hardware
#        . fest
#   . Top bigrams:
#        . hardware fest
#        . machine building
# # 'Java.Expos':
#   . Top unigrams:
#        . hardware
#        . s
#   . Top bigrams:
#        . hardware hackathon
#        . showcase hackathon
# # 'Java.Fests':
#   . Top unigrams:
#        . hardware
#        . design
#   . Top bigrams:
#        . hardware competition
#        . compete win
# # 'Java.Hackathons':
#   . Top unigrams:
#        . workshop
#        . trading
#   . Top bigrams:
#        . join workshop
#        . workshop learn
# # 'Java.Internships':
#   . Top unigrams:
#        . hardware
#        . conference
#   . Top bigrams:
#        . hardware seminar
#        . annual hardware
# # 'Java.Jobs':
#   . Top unigrams:
#        . hardware
#        . intern
#   . Top bigrams:
#        . hardware intern
#        . build machine
# # 'Java.Seminars':
#   . Top unigrams:
#        . hardware
#        . fair
#   . Top bigrams:
#        . construction fair
#        . fair gain
# # 'Java.Talks':
#   . Top unigrams:
#        . hardware
#        . register
#   . Top bigrams:
#        . hardware training
#        . machine building
# # 'Java.Trainings':
#   . Top unigrams:
#        . hardware
#        . job
#   . Top bigrams:
#        . hardware jobs
#        . hardware expert
# # 'Java.Webinars':
#   . Top unigrams:
#        . hardware
#        . certifications
#   . Top bigrams:
#        . hardware expert
#        . advanced certification
# # 'Java.Workshops':
#   . Top unigrams:
#        . hardware
#        . webinar
#   . Top bigrams:
#        . webinar series
#        . ground knowledge
# # 'JavaScript.Certifications':
#   . Top unigrams:
#        . network
#        . networking
#   . Top bigrams:
#        . networking fest
#        . u thing
# # 'JavaScript.Competitions':
#   . Top unigrams:
#        . networking
#        . bootcamp
#   . Top bigrams:
#        . networking network
#        . sign networking
# # 'JavaScript.Courses':
#   . Top unigrams:
#        . networking
#        . network
#   . Top bigrams:
#        . networking intern
#        . contact u
# # 'JavaScript.Fests':
#   . Top unigrams:
#        . networking
#        . expo
#   . Top bigrams:
#        . india s
#        . 3 day
# # 'JavaScript.Hackathons':
#   . Top unigrams:
#        . networking
#        . competition
#   . Top bigrams:
#        . networking competition
#        . design competition
# # 'JavaScript.Internships':
#   . Top unigrams:
#        . networking
#        . network
#   . Top bigrams:
#        . talk networking
#        . networking network
# # 'JavaScript.Jobs':
#   . Top unigrams:
#        . networking
#        . network
#   . Top bigrams:
#        . networking job
#        . networking jobs
# # 'JavaScript.Seminars':
#   . Top unigrams:
#        . networking
#        . hackathon
#   . Top bigrams:
#        . hackathon codeathon
#        . welcome maruti
# # 'JavaScript.Talks':
#   . Top unigrams:
#        . networking
#        . networks
#   . Top bigrams:
#        . build network
#        . webinar series
# # 'JavaScript.Trainings':
#   . Top unigrams:
#        . networking
#        . conference
#   . Top bigrams:
#        . networking seminar
#        . networks networking
# # 'JavaScript.Webinars':
#   . Top unigrams:
#        . networking
#        . course
#   . Top bigrams:
#        . networking course
#        . build network
# # 'JavaScript.Workshops':
#   . Top unigrams:
#        . networking
#        . workshop
#   . Top bigrams:
#        . networking workshop
#        . free networking
# # 'ML.Certifications':
#   . Top unigrams:
#        . learning
#        . machine
#   . Top bigrams:
#        . talk machine
#        . machine learning
# # 'ML.Certifications.Courses':
#   . Top unigrams:
#        . workshop
#        . web
#   . Top bigrams:
#        . development workshop
#        . web development
# # 'ML.Competitions':
#   . Top unigrams:
#        . management
#        . online
#   . Top bigrams:
#        . u live
#        . free webinar
# # 'ML.Courses':
#   . Top unigrams:
#        . learning
#        . machine
#   . Top bigrams:
#        . machine learning
#        . build machine
# # 'ML.Expos':
#   . Top unigrams:
#        . web
#        . host
#   . Top bigrams:
#        . development jobs
#        . web developer
# # 'ML.Fests':
#   . Top unigrams:
#        . ml
#        . conference
#   . Top bigrams:
#        . annual machine
#        . talk machine
# # 'ML.Hackathons':
#   . Top unigrams:
#        . learning
#        . design
#   . Top bigrams:
#        . learning intern
#        . machine learning
# # 'ML.Internships':
#   . Top unigrams:
#        . management
#        . hackathon
#   . Top bigrams:
#        . management hackathon
#        . 2020 hackathon
# # 'ML.Jobs':
#   . Top unigrams:
#        . workshop
#        . learning
#   . Top bigrams:
#        . learning workshop
#        . machine learning
# # 'ML.Seminars':
#   . Top unigrams:
#        . learning
#        . machine
#   . Top bigrams:
#        . machine learning
#        . learning ml
# # 'ML.Talks':
#   . Top unigrams:
#        . associate
#        . e
#   . Top bigrams:
#        . available naukri
#        . stand rest
# # 'ML.Trainings':
#   . Top unigrams:
#        . management
#        . expo
#   . Top bigrams:
#        . attend free
#        . expos fairs
# # 'ML.Webinars':
#   . Top unigrams:
#        . job
#        . learning
#   . Top bigrams:
#        . learning jobs
#        . machine learning
# # 'ML.Workshops':
#   . Top unigrams:
#        . app
#        . contest
#   . Top bigrams:
#        . mobile applications
#        . apple ios
# # 'Management.Expos':
#   . Top unigrams:
#        . blockchain
#        . cryptocurrency
#   . Top bigrams:
#        . blockchain fest
#        . u grandest
# # 'Management.Hackathons':
#   . Top unigrams:
#        . certification
#        . today
#   . Top bigrams:
#        . certified professional
#        . artificial intelligence
# # 'Management.Webinars':
#   . Top unigrams:
#        . help
#        . want
#   . Top bigrams:
#        . join course
#        . days left
# # 'Mobile_Applications.Certifications':
#   . Top unigrams:
#        . programmer
#        . certificate
#   . Top bigrams:
#        . multiple c++
#        . certified associate
# # 'Mobile_Applications.Competitions':
#   . Top unigrams:
#        . senior
#        . dream
#   . Top bigrams:
#        . c++ developer
#        . developer position
# # 'Mobile_Applications.Courses':
#   . Top unigrams:
#        . udemy
#        . course
#   . Top bigrams:
#        . c++ programming
#        . special discount
# # 'Mobile_Applications.Expos':
#   . Top unigrams:
#        . experience
#        . c++
#   . Top bigrams:
#        . c++ fair
#        . begin tomorrow
# # 'Mobile_Applications.Fests':
#   . Top unigrams:
#        . coding
#        . webinar
#   . Top bigrams:
#        . u live
#        . live webinar
# # 'Mobile_Applications.Hackathons':
#   . Top unigrams:
#        . coding
#        . biggest
#   . Top bigrams:
#        . join seminar
#        . conference today
# # 'Mobile_Applications.Internships':
#   . Top unigrams:
#        . enterprise
#        . c++
#   . Top bigrams:
#        . internship available
#        . stand peer
# # 'Mobile_Applications.Jobs':
#   . Top unigrams:
#        . festival
#        . weekend
#   . Top bigrams:
#        . annual c++
#        . c++ enthusiasts
# # 'Mobile_Applications.Seminars':
#   . Top unigrams:
#        . c++
#        . plethora
#   . Top bigrams:
#        . quiz stand
#        . don t
# # 'Mobile_Applications.Talks':
#   . Top unigrams:
#        . seminars
#        . conference
#   . Top bigrams:
#        . modern c++
#        . seminar series
# # 'Mobile_Applications.Trainings':
#   . Top unigrams:
#        . challenge
#        . core
#   . Top bigrams:
#        . c++ hackathon
#        . hackathon stand
# # 'Mobile_Applications.Webinars':
#   . Top unigrams:
#        . better
#        . programming
#   . Top bigrams:
#        . talks speeches
#        . attend speech
# # 'Mobile_Applications.Workshops':
#   . Top unigrams:
#        . c++
#        . practises
#   . Top bigrams:
#        . c++ enthusiasts
#        . hackathon stand
# # 'Network.Certifications':
#   . Top unigrams:
#        . java
#        . introduction
#   . Top bigrams:
#        . u online
#        . learn java
# # 'Networking.Competitions':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . js skill
#        . hackathon codeathon
# # 'Networking.Courses':
#   . Top unigrams:
#        . javascript
#        . certification
#   . Top bigrams:
#        . javascript expert
#        . advanced javascript
# # 'Networking.Expos':
#   . Top unigrams:
#        . web
#        . hackathon
#   . Top bigrams:
#        . web development
#        . codeathon sign
# # 'Networking.Fests':
#   . Top unigrams:
#        . bootcamps
#        . java
#   . Top bigrams:
#        . core java
#        . bootcamps training
# # 'Networking.Hackathons':
#   . Top unigrams:
#        . seminar
#        . field
#   . Top bigrams:
#        . learn java
#        . oracle java
# # 'Networking.Internships':
#   . Top unigrams:
#        . js
#        . fest
#   . Top bigrams:
#        . javascript fest
#        . fest year
# # 'Networking.Jobs':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . javascript competition
#        . competition quiz
# # 'Networking.Seminars':
#   . Top unigrams:
#        . events
#        . workshops
#   . Top bigrams:
#        . java workshop
#        . 3 day
# # 'Networking.Talks':
#   . Top unigrams:
#        . javascript
#        . framework
#   . Top bigrams:
#        . javascript intern
#        . js framework
# # 'Networking.Trainings':
#   . Top unigrams:
#        . javascript
#        . course
#   . Top bigrams:
#        . advanced javascript
#        . sign javascript
# # 'Networking.Webinars':
#   . Top unigrams:
#        . java
#        . language
#   . Top bigrams:
#        . java talk
#        . talk series
# # 'Networking.Workshops':
#   . Top unigrams:
#        . javascript
#        . job
#   . Top bigrams:
#        . host javascript
#        . javascript expert
# # 'None.Competitions':
#   . Top unigrams:
#        . conference
#        . galore
#   . Top bigrams:
#        . learn latest
#        . seminars conferences
# # 'Python.Certifications':
#   . Top unigrams:
#        . computing
#        . cloud
#   . Top bigrams:
#        . talk cloud
#        . cloud computing
# # 'Python.Competitions':
#   . Top unigrams:
#        . cloud
#        . fest
#   . Top bigrams:
#        . computing fest
#        . cloud computing
# # 'Python.Courses':
#   . Top unigrams:
#        . cloud
#        . seminar
#   . Top bigrams:
#        . talk cloud
#        . cloud computing
# # 'Python.Expos':
#   . Top unigrams:
#        . cloud
#        . internships
#   . Top bigrams:
#        . computing intern
#        . cloud computing
# # 'Python.Fests':
#   . Top unigrams:
#        . cloud
#        . certification
#   . Top bigrams:
#        . computing expert
#        . cloud computing
# # 'Python.Hackathons':
#   . Top unigrams:
#        . workshop
#        . c
#   . Top bigrams:
#        . attend host
#        . c language
# # 'Python.Internships':
#   . Top unigrams:
#        . computer
#        . cloud
#   . Top bigrams:
#        . world cloud
#        . explore world
# # 'Python.Jobs':
#   . Top unigrams:
#        . cloud
#        . competition
#   . Top bigrams:
#        . computing competition
#        . cloud computing
# # 'Python.Seminars':
#   . Top unigrams:
#        . azure
#        . cloud
#   . Top bigrams:
#        . aws cloud
#        . today proficiency
# # 'Python.Talks':
#   . Top unigrams:
#        . job
#        . cloud
#   . Top bigrams:
#        . host cloud
#        . cloud computing
# # 'Python.Trainings':
#   . Top unigrams:
#        . course
#        . computing
#   . Top bigrams:
#        . cloud computing
#        . pro course
# # 'Python.Webinars':
#   . Top unigrams:
#        . c
#        . webinar
#   . Top bigrams:
#        . c programming
#        . live webinar
# # 'Python.Workshops':
#   . Top unigrams:
#        . computing
#        . bootcamp
#   . Top bigrams:
#        . cloud computing
#        . host cloud
# # 'Security.Certifications':
#   . Top unigrams:
#        . required
#        . bank
#   . Top bigrams:
#        . job opportunity
#        . artificial intelligence
# # 'Security.Competitions':
#   . Top unigrams:
#        . software
#        . finally
#   . Top bigrams:
#        . architecture fair
#        . software architecture
# # 'Security.Courses':
#   . Top unigrams:
#        . security
#        . workshop
#   . Top bigrams:
#        . security workshop
#        . workshop fair
# # 'Security.Expos':
#   . Top unigrams:
#        . advance
#        . intermediate
#   . Top bigrams:
#        . want learn
#        . comprehensive webinars
# # 'Security.Fests':
#   . Top unigrams:
#        . security
#        . webinar
#   . Top bigrams:
#        . security webinar
#        . online webinar
# # 'Security.Hackathons':
#   . Top unigrams:
#        . security
#        . bootcamp
#   . Top bigrams:
#        . sign security
#        . cyber security
# # 'Security.Internships':
#   . Top unigrams:
#        . course
#        . architecture
#   . Top bigrams:
#        . architecture course
#        . sign networking
# # 'Security.Jobs':
#   . Top unigrams:
#        . architecture
#        . certification
#   . Top bigrams:
#        . certified expert
#        . software architecture
# # 'Security.Seminars':
#   . Top unigrams:
#        . intern
#        . internship
#   . Top bigrams:
#        . ai internship
#        . work home
# # 'Security.Talks':
#   . Top unigrams:
#        . software
#        . fest
#   . Top bigrams:
#        . architecture fest
#        . software kernel
# # 'Security.Trainings':
#   . Top unigrams:
#        . competition
#        . architecture
#   . Top bigrams:
#        . architecture competition
#        . software architecture
# # 'Security.Webinars':
#   . Top unigrams:
#        . hackathon
#        . year
#   . Top bigrams:
#        . hackathon today
#        . artificial intelligence
# # 'Security.Workshops':
#   . Top unigrams:
#        . architecture
#        . hackathon
#   . Top bigrams:
#        . software architecture
#        . related events
# # 'Software_Architecture.Certifications':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . build javascript
#        . javascript js
# # 'Software_Architecture.Competitions':
#   . Top unigrams:
#        . ml
#        . finally
#   . Top bigrams:
#        . machine learning
#        . join fellow
# # 'Software_Architecture.Courses':
#   . Top unigrams:
#        . certification
#        . learning
#   . Top bigrams:
#        . machine learning
#        . learning expert
# # 'Software_Architecture.Expos':
#   . Top unigrams:
#        . web
#        . website
#   . Top bigrams:
#        . build website
#        . web dev
# # 'Software_Architecture.Fests':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . javascript js
#        . sign javascript
# # 'Software_Architecture.Hackathons':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . talk javascript
#        . today discover
# # 'Software_Architecture.Internships':
#   . Top unigrams:
#        . comprehensive
#        . machine
#   . Top bigrams:
#        . learning course
#        . ml course
# # 'Software_Architecture.Jobs':
#   . Top unigrams:
#        . course
#        . ml
#   . Top bigrams:
#        . ml course
#        . machine learning
# # 'Software_Architecture.Seminars':
#   . Top unigrams:
#        . javascript
#        . workshop
#   . Top bigrams:
#        . javascript workshop
#        . javascript fair
# # 'Software_Architecture.Talks':
#   . Top unigrams:
#        . ml
#        . fest
#   . Top bigrams:
#        . learning fest
#        . machine learning
# # 'Software_Architecture.Trainings':
#   . Top unigrams:
#        . competition
#        . ml
#   . Top bigrams:
#        . learning competition
#        . machine learning
# # 'Software_Architecture.Webinars':
#   . Top unigrams:
#        . javascript
#        . js
#   . Top bigrams:
#        . talk javascript
#        . javascript expert
# # 'Software_Architecture.Workshops':
#   . Top unigrams:
#        . ml
#        . hackathon
#   . Top bigrams:
#        . machine learning
#        . learning ml
# # 'WebDev.Certifications':
#   . Top unigrams:
#        . path
#        . shahani
#   . Top bigrams:
#        . sign higher
#        . education degree
# # 'WebDev.Competitions':
#   . Top unigrams:
#        . seminar
#        . education
#   . Top bigrams:
#        . higher education
#        . university degree
# # 'WebDev.Courses':
#   . Top unigrams:
#        . education
#        . explore
#   . Top bigrams:
#        . education fest
#        . education degree
# # 'WebDev.Expos':
#   . Top unigrams:
#        . development
#        . web
#   . Top bigrams:
#        . development course
#        . web development
# # 'WebDev.Fests':
#   . Top unigrams:
#        . scholarship
#        . university
#   . Top bigrams:
#        . education competition
#        . competition quiz
# # 'WebDev.Hackathons':
#   . Top unigrams:
#        . hardware
#        . workshop
#   . Top bigrams:
#        . hardware workshop
#        . free hardware
# # 'WebDev.Internships':
#   . Top unigrams:
#        . counselling
#        . education
#   . Top bigrams:
#        . education jobs
#        . higher education
# # 'WebDev.Jobs':
#   . Top unigrams:
#        . university
#        . want
#   . Top bigrams:
#        . attend higher
#        . higher education
# # 'WebDev.Seminars':
#   . Top unigrams:
#        . fair
#        . college
#   . Top bigrams:
#        . education expo
#        . attend higher
# # 'WebDev.Talks':
#   . Top unigrams:
#        . choose
#        . degree
#   . Top bigrams:
#        . choose right
#        . choose higher
# # 'WebDev.Trainings':
#   . Top unigrams:
#        . student
#        . teacher
#   . Top bigrams:
#        . internship opportunity
#        . needed handle
# # 'WebDev.Webinars':
#   . Top unigrams:
#        . rated
#        . degree
#   . Top bigrams:
#        . education certification
#        . university today
# # 'WebDev.Workshops':
#   . Top unigrams:
#        . training
#        . bootcamp
#   . Top bigrams:
#        . education training
#        . higher education

# %%
id_to_category
# Out:
# {0: 'Management.Hackathons',
#  1: 'Management.Webinars',
#  2: 'Coding.Hackathons',
#  3: 'Other.Hackathons',
#  4: 'Coding.Webinars',
#  5: 'Coding.Seminars',
#  6: 'Security.Webinars',
#  7: 'Security.Seminars',
#  8: 'Other.Certifications',
#  9: 'Security.Certifications',
#  10: 'Other.Competitions',
#  11: 'Management.Trainings',
#  12: 'Other.Webinar',
#  13: 'Higher_Education.Trainings',
#  14: 'Higher_Education.Internships',
#  15: 'Higher_Education.Webinars',
#  16: 'Higher_Education.Expos',
#  17: 'Higher_Education.Seminars',
#  18: 'Management.Expos',
#  19: 'Coding.Fests',
#  20: 'Coding.Internships',
#  21: 'Coding.Jobs',
#  22: 'Coding.Expos',
#  23: 'Coding.Certifications',
#  24: 'Coding.Talks',
#  25: 'Coding.Competitions',
#  26: 'Artificial_Intelligence.Hackathons',
#  27: 'Artificial_Intelligence.Webinars',
#  28: 'Artificial_Intelligence.Fests',
#  29: 'Artificial_Intelligence.Seminars',
#  30: 'Artificial_Intelligence.Expos',
#  31: 'Artificial_Intelligence.Certifications',
#  32: 'Artificial_Intelligence.Trainings',
#  33: 'Artificial_Intelligence.Courses',
#  34: 'Artificial_Intelligence.Jobs',
#  35: 'Artificial_Intelligence.Internships',
#  36: 'Artificial_Intelligence.Talks',
#  37: 'Python.Webinars',
#  38: 'Python.Hackathons',
#  39: 'Python.Fests',
#  40: 'Python.Jobs',
#  41: 'Python.Trainings',
#  42: 'Python.Internships',
#  43: 'Python.Competitions',
#  44: 'Python.Seminars',
#  45: 'Python.Expos',
#  46: 'Python.Talks',
#  47: 'Python.Courses',
#  48: 'Python.Certifications',
#  49: 'Python.Workshops',
#  50: 'Finance.Hackathons',
#  51: 'Finance.Webinars',
#  52: 'Finance.Talks',
#  53: 'Finance.Fests',
#  54: 'Finance.Courses',
#  55: 'Finance.Certifications',
#  56: 'Finance.Seminars',
#  57: 'Finance.Jobs',
#  58: 'Finance.Internships',
#  59: 'Finance.Workshops',
#  60: 'Mobile_Applications.Hackathons',
#  61: 'Mobile_Applications.Webinars',
#  62: 'Mobile_Applications.Fests',
#  63: 'Mobile_Applications.Certifications',
#  64: 'Mobile_Applications.Seminars',
#  65: 'Mobile_Applications.Courses',
#  66: 'Mobile_Applications.Expos',
#  67: 'Mobile_Applications.Jobs',
#  68: 'Mobile_Applications.Trainings',
#  69: 'Mobile_Applications.Internships',
#  70: 'Mobile_Applications.Competitions',
#  71: 'Mobile_Applications.Talks',
#  72: 'Mobile_Applications.Workshops',
#  73: 'Cpp.Hackathons',
#  74: 'Cpp.Webinars',
#  75: 'Cpp.Fests',
#  76: 'Cpp.Certifications',
#  77: 'Cpp.Seminars',
#  78: 'Cpp.Courses',
#  79: 'Cpp.Expos',
#  80: 'Cpp.Jobs',
#  81: 'Cpp.Trainings',
#  82: 'Cpp.Internships',
#  83: 'Cpp.Competitions',
#  84: 'Cpp.Talks',
#  85: 'Cpp.Workshops',
#  86: 'C.Hackathons',
#  87: 'C.Webinars',
#  88: 'C.Fests',
#  89: 'C.Certifications',
#  90: 'C.Seminars'}

# %%
texts = ["Get a job as a senior Python Developer Now with our certification!",
         "The World's largest python conference is out now",
         "Expo: The advent of ai",
         "Stand out with this comprehensive course on finance and investments",
         "COHO C++ Festival and competition begins soon. Book your Tickets today!"]
text_features = tfidf.transform(texts)
predictions = model.predict(text_features)
for text, predicted in zip(texts, predictions):
  print('"{}"'.format(text))
  print("  - Predicted as: '{}'".format(predicted))
  print("")
# Out:
# "Get a job as a senior Python Developer Now with our certification!"
#   - Predicted as: 'Python.Jobs'
#
# "The World's largest python conference is out now"
#   - Predicted as: 'Python.Seminars'
#
# "Expo: The advent of ai"
#   - Predicted as: 'Artificial_Intelligence.Expos'
#
# "Stand out with this comprehensive course on finance and investments"
#   - Predicted as: 'Finance.Courses'
#
# "COHO C++ Festival and competition begins soon. Book your Tickets today!"
#   - Predicted as: 'Mobile_Applications.Fests'

# %%
from sklearn.feature_extraction import text
my_stops = text.ENGLISH_STOP_WORDS.difference(["AI", "ai"])

vectorizer = TfidfVectorizer(ngram_range=(1,1), stop_words=my_stops)

X = vectorizer.fit_transform(["this is an AI apple.","get your ai course today"])

idf_values = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))

# printing the tfidf vectors
print(X)

# printing the vocabulary
print(vectorizer.vocabulary_)
# Out:
#   (0, 1)	0.8148024746671689
#   (0, 0)	0.5797386715376657
#   (1, 3)	0.6316672017376245
#   (1, 2)	0.6316672017376245
#   (1, 0)	0.4494364165239821
# {'ai': 0, 'apple': 1, 'course': 2, 'today': 3}

# %%
def get_query(event_dom, event_type, employees):
    return employees.query("Domain == '" + event_dom + "' and (Event1 == '" + event_type +"' or Event2 == '" + event_type + "')")

# %%
def predict(events, employees):
    #for event in events:
        #print(type(event))
        recommendations = []
        pred = model.predict(tfidf.transform(events))
        
        for text, predicted in zip(events, pred):
          print('"{}"'.format(text))
          print("  - Predicted as: '{}'".format(predicted))
          print("")

        for prediction in pred.tolist():
            domain, event_type = prediction.split(".")
            if domain == 'Artificial_Intelligence':
                #recommend_to = employees.loc[employees['Domain'] == "Artificial Intelligence" and (employees['Event1'] == event_type or employees['Event2'] == event_type) , 'Name'].all()
                recommend_to = get_query('Artificial Intelligence', event_type, employees)
                
            elif domain == 'WebDev':
                recommend_to = get_query('Web Development', event_type, employees)
                
            elif domain == 'Mobile_Applications':
                recommend_to = get_query('Mobile Applications', event_type, employees)
                
            elif domain == 'ML':
                recommend_to = get_query('Machine Learning', event_type, employees)
                
            elif domain == 'CC':
                recommend_to = get_query('Cloud Computing', event_type, employees)
                
            elif domain == 'Higher_Education':
                recommend_to = get_query('Higher Education', event_type, employees)
                
            elif domain == 'DevOps':
                recommend_to = get_query('Development Processes', event_type, employees)
                
            elif domain == 'Software_Architecture':
                recommend_to = get_query('Software Architecture', event_type, employees)
                
            elif domain == 'Data_Science':
                recommend_to = get_query('Data Science', event_type, employees)
                
            elif domain == 'Cpp':
                recommend_to = get_query('C++', event_type, employees)
                
            elif domain == 'None':
                recommend_to = employees.query("Event1 == '" + event_type + "' or Event2 == '" + event_type + "'")
                
            else:
                recommend_to = get_query(domain, event_type, employees)
                
            recommendations.append(", ".join(recommend_to['Name'].values))
            
        return recommendations

# %%
def make_predictions():
    employees = pd.read_csv("CCMLEmployeeData.csv")
    
    to_pred = input("Please enter the file: ")
    
    to_pred_events = pd.read_csv(to_pred)
    to_pred_sent = split_lemma(to_pred_events.Events)
    recommendations = predict(to_pred_sent, employees)
    #print(recommendations)
    to_pred_events['Employees'] = recommendations
    to_pred_events.to_csv(to_pred, index=False)

# %%
make_predictions()
# Out:
# Please enter the file: event_test.csv
# "Get a job a a senior Python Developer Now!"
#   - Predicted as: 'Coding.Jobs'
#
# "The World's largest python conference is out now"
#   - Predicted as: 'Python.Seminars'
#
# "Expo: The advent of ai"
#   - Predicted as: 'Artificial_Intelligence.Talks'
#
# "Stand out with this comprehensive course on finance and investment"
#   - Predicted as: 'Finance.Courses'
#
# "COHO C++ Festival begin soon. Book your Tickets today!"
#   - Predicted as: 'Cpp.Fests'
#
# "Attend a javascript course"
#   - Predicted as: 'JavaScript.Courses'
#
# "Blockchain and more! A Talk by Switcha Chadda"
#   - Predicted as: 'Blockchain.Webinars'
#
# "Oxywatch ML Hackathon"
#   - Predicted as: 'ML.Hackathons'
#
# "Attend a security webinar today"
#   - Predicted as: 'Security.Webinars'
#
# "Talk on cyber securty by the leading security expert"
#   - Predicted as: 'Security.Talks'
#
# "join u for a data science course"
#   - Predicted as: 'Data_Science.Courses'
#
# "Expos: The JS fair is here"
#   - Predicted as: 'JS.Expos'
#
# "Discover the beauty of cloud computing with this certification"
#   - Predicted as: 'CC.Certifications'
#
# "Participate in our Software architecture competition"
#   - Predicted as: 'Software_Architecture.Competitions'
#
# "Join our webinar on security"
#   - Predicted as: 'Security.Webinars'
#
# "The Artificial Intelligence expo is here"
#   - Predicted as: 'Artificial_Intelligence.Expos'
#
# "Join the annual AI fair"
#   - Predicted as: 'Artificial_Intelligence.Hackathons'
#
# "Join the ML expo today"
#   - Predicted as: 'Artificial_Intelligence.Expos'
#
# "Cyber security webinar alert"
#   - Predicted as: 'Security.Webinars'
#
# "Competitions and more: compete in the web development pharma event today"
#   - Predicted as: 'C.Competitions'
#
# "Eplore blockchains in the expert blockchain coonference"
#   - Predicted as: 'Blockchain.Talks'
#
# "Calling all hardware enthusiast to this one of a kind fair"
#   - Predicted as: 'Hardware.Expos'
#
# "Join u in the dustbin hackathon today"
#   - Predicted as: 'Other.Hackathon'
#
# "HandBag have come up with their own carpentry hackathon. Please do participate"
#   - Predicted as: 'None.Hackathon'
#
# "Join codevita for a hackathon"
#   - Predicted as: 'None.Hackathon'
#
# "Hackathon alert: hackathon tomorrow"
#   - Predicted as: 'Finance.Hackathons'
#
# "A new machine learning certification course is out now"
#   - Predicted as: 'ML.Certifications'
#
# "Become a certified machine learning engineer with our new series of ML course"
#   - Predicted as: 'ML.Certifications.Courses'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-38a781d6d3f2> in <module>
# ----> 1 make_predictions()
#
# <ipython-input-20-bfc398ecb64c> in make_predictions()
#       6     to_pred_events = pd.read_csv(to_pred)
#       7     to_pred_sent = split_lemma(to_pred_events.Events)
# ----> 8     recommendations = predict(to_pred_sent, employees)
#       9     #print(recommendations)
#      10     to_pred_events['Employees'] = recommendations
#
# <ipython-input-19-e35714cb25d1> in predict(events, employees)
#      11
#      12         for prediction in pred.tolist():
# ---> 13             domain, event_type = prediction.split(".")
#      14             if domain == 'Artificial_Intelligence':
#      15                 #recommend_to = employees.loc[employees['Domain'] == "Artificial Intelligence" and (employees['Event1'] == event_type or employees['Event2'] == event_type) , 'Name'].all()
#
# ValueError: too many values to unpack (expected 2)

# %%
employees = pd.read_csv("CCMLEmployeeData.csv")
recommend = employees.query("Domain == 'Hardware' and  Event2 == 'Webinars'")
print(recommend)
# Out:
#                 Name    Domain        Event1    Event2
# 3    Dustin Ferguson  Hardware  Competitions  Webinars
# 106  Tanya Armstrong  Hardware  Competitions  Webinars

# %%
from sklearn.linear_model import SGDClassifier
#y_pred = model.predict(X_test)
model2 = SGDClassifier()
#model2.fit(features, labels)

# %%
texts = ["Get a job as a senior Python Developer Now with our certification!",
         "The World's largest python conference is out now",
         "Expo: The advent of ai",
         "Stand out with this comprehensive course on finance and investments",
         "COHO C++ Festival and competition begins soon. Book your Tickets today!"]
text_features = tfidf.transform(texts)
predictions = model2.predict(text_features)
for text, predicted in zip(texts, predictions):
  print('"{}"'.format(text))
  print("  - Predicted as: '{}'".format(predicted))
  print("")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-23-04bc9a633ce9> in <module>
#       5          "COHO C++ Festival and competition begins soon. Book your Tickets today!"]
#       6 text_features = tfidf.transform(texts)
# ----> 7 predictions = model2.predict(text_features)
#       8 for text, predicted in zip(texts, predictions):
#       9   print('"{}"'.format(text))
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     291             Predicted class label per sample.
#     292         """
# --> 293         scores = self.decision_function(X)
#     294         if len(scores.shape) == 1:
#     295             indices = (scores > 0).astype(np.int)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     264             class would be predicted.
#     265         """
# --> 266         check_is_fitted(self)
#     267
#     268         X = check_array(X, accept_sparse='csr')
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     950
#     951     if not attrs:
# --> 952         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     953
#     954
#
# NotFittedError: This SGDClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
texts = ["COHO C++ Festival and competition begins soon. Book your Tickets today!"]
text_features = tfidf.transform(texts)
#predictions = model2.predict(text_features)

# %%
from sklearn.calibration import CalibratedClassifierCV
calibrated_clf = CalibratedClassifierCV(model2, cv=2, method='sigmoid')
model = calibrated_clf.fit(features, labels)

probs = model.predict_proba(text_features)
sorted( zip( calibrated_clf.classes_, probs[0] ), key=lambda x:x[1] )[-n:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-bdf891ff30cf> in <module>
#       1 from sklearn.calibration import CalibratedClassifierCV
#       2 calibrated_clf = CalibratedClassifierCV(model2, cv=2, method='sigmoid')
# ----> 3 model = calibrated_clf.fit(features, labels)
#       4
#       5 probs = model.predict_proba(text_features)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\calibration.py in fit(self, X, y, sample_weight)
#     147             raise ValueError("Requesting %d-fold cross-validation but provided"
#     148                              " less than %d examples for at least one class."
# --> 149                              % (n_folds, n_folds))
#     150
#     151         self.calibrated_classifiers_ = []
#
# ValueError: Requesting 2-fold cross-validation but provided less than 2 examples for at least one class.
