# %%
import numpy as np
import pandas as pd

# %%
events = pd.read_excel("Event.xlsx")

# %%
events
# Out:
#                                                 Events                   Type  \
# 0             Introducing The Management 2.0 Hackathon  Management.Hackathons
# 1    Join us live online on September 10th at 9:30 ...    Management.Webinars
# 2    Learn and practise your delegation skills with...    Management.Webinars
# 3    Upcoming Online Seminar: The Future of Managem...    Management.Webinars
# 4    World's biggest coding event - TechGig Code Gl...           Coding.Fests
# ..                                                 ...                    ...
# 430  Come down to many one of our expos or fairs an...             Java.Expos
# 431         Java Developer Job Opportunity - Core Java              Java.Jobs
# 432            Full time Java developer jobs in mumbai              Java.Jobs
# 433  Full Time Junior Java Excecutive Position at O...              Java.Jobs
# 434  Plethora of jobs Java jobs available at intern...              Java.Jobs
#
#     Unnamed: 2
# 0          NaN
# ...

# %%
target_names = events.Type.unique().tolist()

# %%
target_names
# Out:
# ['Management.Hackathons',
#  'Management.Webinars',
#  'Coding.Fests',
#  'None.Hackathons',
#  'Other.Hackathons',
#  'Other.Webinars',
#  'Coding.Webinars',
#  'Other.Seminars',
#  'Dat_Science.Seminars',
#  'Security.Webinars',
#  'Security.Seminars',
#  'Other.Certifications',
#  'Coding.Hackathons',
#  'Security.Certifications',
#  'None.Competitions',
#  'Finance.Competitions',
#  'Management.Trainings',
#  'Finance.Webinars',
#  'Higher_Education.Trainings',
#  'Higher_Education.Internships',
#  'Higher_Education.Webinars',
#  'Higher_Education.Expos',
#  'Higher_Education.Seminars',
#  'Management.Expos',
#  'Coding.Internships',
#  'Coding.Jobs',
#  'Coding.Seminars',
#  'Coding.Expos',
#  'Coding.Certifications',
#  'Coding.Talks',
#  'Coding.Competitions',
#  'Artificial_Intelligence.Hackathons',
#  'Artificial_Intelligence.Webinars',
#  'Artificial_Intelligence.Fests',
#  'Artificial_Intelligence.Seminars',
#  'Artificial_Intelligence.Expos',
# ...

# %%
events.Events.str.lower().values
# Out:
# array(['introducing the management 2.0 hackathon',
#        'join us live online on september 10th at 9:30 am to learn how to take your in-person training online in 6 simple steps with our management series.',
#        'learn and practise your\xa0delegation skills\xa0with this 1-hour free webinar for managers.',
#        'upcoming online seminar: the future of management: agile leadership and management 3.0',
#        "world's biggest coding event - techgig code gladiators - is back with its 7th edition",
#        'adobe codiva – international women’s day\xa0hackathon\xa02020.',
#        'register now - accenture hack diva 2020-\xa0hackathon\xa0for women in engineering',
#        'webinar: what is ux/ui design? a code perspective',
#        'teaching coding online with this free webinar',
#        'live panel and discussion on covid-19 recovery planning using advanced analytics',
#        'seminar on how to use alternative data to understand the covid economy',
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(events.Events.values, events.Type.values, test_size=0.2, shuffle = True, random_state=42)

# %%
# Extracting features from text files
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import text
my_stops = text.ENGLISH_STOP_WORDS.difference(["AI", "ai"])

count_vect = CountVectorizer(ngram_range=(1, 2), stop_words = my_stops, token_pattern = r"(?u)c\+{2}|\b\w+\b")
X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (348, 2406)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import text
my_stops = text.ENGLISH_STOP_WORDS.difference(["AI", "ai"])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (348, 2406)

# %%
count_vect.get_feature_names()
# Out:
# ['0',
#  '030',
#  '030 modern',
#  '1',
#  '1 3',
#  '1 hour',
#  '101',
#  '101 workshop',
#  '10th',
#  '10th 9',
#  '19',
#  '19 world',
#  '1more',
#  '1more sign',
#  '2',
#  '2 week',
#  '2018',
#  '2018 finance',
#  '2019',
#  '2019 codechef',
#  '2020',
#  '2020 26',
#  '2020 c++',
#  '2020 dates',
#  '2020 hackathon',
#  '2020 mobile',
#  '2020 nearing',
#  '2020 online',
#  '2020 python',
#  '26',
#  '26 july',
#  '3',
#  '3 0',
#  '3 day',
#  '3 introduction',
#  '3 month',
#  '30',
#  '30 july',
#  '30 learn',
#  '340',
#  '340 340',
#  '340 gre',
#  '4',
#  '4 java',
#  '5',
#  '5 day',
#  '5 days',
#  '6',
#  '6 days',
#  '6 simple',
#  '7',
#  '7 days',
#  '7 ranked',
#  '7th',
#  '7th edition',
#  '9',
#  '9 30',
#  'academic',
#  'academic writer',
#  'accenture',
#  'accenture hack',
#  'accessing',
#  'accessing free',
#  'accounting',
#  'accounting finance',
#  'adaboost',
#  'adaboost c++',
#  'add',
#  'add amazing',
#  'add python',
#  'adobe',
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
from sklearn.pipeline import Pipeline

text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1, 2), stop_words = my_stops)), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])

text_clf = text_clf.fit(X_train, y_train)

# %%
import numpy as np
predicted = text_clf.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.04597701149425287

# %%
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer(ngram_range=(1, 2), stop_words = my_stops)), ('tfidf', TfidfTransformer()),
                         ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, max_iter=20, random_state=42))])

text_clf_svm = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)
for i in range(len(X_test)):
    if i%3 == 0:
        print(X_test[i] + " : "+ predicted_svm[i] + " : " + y_test[i])
np.mean(predicted_svm == y_test)
# Out:
# Single- and double session Advanced C++ Seminars : C.Seminars : Cpp.Seminars
# Android Application Development Workshop for Engineering : Mobile_Applications.Workshops : Mobile_Applications.Workshops
# Experience C++ and much more at the CodeShastra C++ Design Expo : C.Expos : Cpp.Expos
# JOIN THE JAVA WEBINAR SERIES BY CODESHASTRA : C.Webinars : Java.Webinars
# Expos & Fairs : The Annual JavaWorld Java Fair : Cpp.Expos : Java.Expos
# Artificial Intelligence (AI) Internship in Sathupally at RuralFolks : Artificial_Intelligence.Certifications : Artificial_Intelligence.Internships
# Job Opportunity Alert! Full Time Artificial Intelligence Specialist Position Available at Cloud Counselage : Cpp.Jobs : Artificial_Intelligence.Jobs
# Join the JAVA Codeathon today! : Mobile_Applications.Hackathons : Java.Hackathons
# Job Alert! Join XL Dynamics' Elite Team of Financial Analysts - Interview @ Home : Cpp.Jobs : Finance.Jobs
# ...
